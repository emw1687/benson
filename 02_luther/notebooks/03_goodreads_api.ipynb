# %% [markdown]
# ### Goal: use the Goodreads API to gather data about books and authors on the _New York Times_ Fiction Best Sellers list for a range of years between 1942-2016
#
# * General Search
# * Get data by author id
# * Get data by book id

# %%
import requests
import urllib

from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import xml.dom.minidom
from lxml import etree

from time import sleep

import re

import pandas as pd
import numpy as np

import pickle

# %%
#goodreads api key
key = '2Kp7IGlO7GKjmAASOT2pEw'

# %%
with open('../data/interim/books_dict.pkl', 'rb') as picklefile:
    books = pickle.load(picklefile)

# %%
#books['A Tree Grows in Brooklyn']

# %%
def try_url(url):
    '''
    Attempt to access Goodreads page
    '''
    response = requests.get(url)
    status = response.status_code
    if status != 200:
        print status
    else:
        page = response.text
        soup = BeautifulSoup(page, 'xml')
        return soup

# %% [markdown]
# ### General Search
# url = https://www.goodreads.com/search.xml?key=YOUR_KEY&q=Ender%27s+Game
#
# Requires
# * Title of book
#
# Returns
# * first item in results>work
#     * books_count: number of versions
#     * id: Goodreads ID
#     * original_publication_day: publication day
#     * original_publication_month: publication month
#     * original_publication_year: publication year
#     * average_rating: average rating
#     * ratings_count: number of ratings
#     * text_reviews_count: number of text reviews
# * first item in results>work>best_book>author
#     * id: author ID

# %%
search_base_url = 'https://www.goodreads.com/search.xml?'
search_criteria = {'key': key,
                  'q': None}

#books = {'A Tree Grows in Brooklyn' : 'Betty  Smith'}

search_urls = {}

for nyt_title, author in books.items():
    search_criteria['q'] = nyt_title + ' ' + author
    url = search_base_url + urllib.urlencode(search_criteria)
    search_urls[url] = [author, nyt_title]

# %%
def get_search_data(works, author, nyt_title, df):
    '''
    Retrieve data from works xml tree from search results page
    '''
    for work in works:
        if work.find('best_book/author/name').text == author:
            b_id = work.find('best_book/id').text
            gr_title = work.find('best_book/title').text
            b_count = work.find('books_count').text
            pub_day = work.find('original_publication_day').text
            pub_mon = work.find('original_publication_month').text
            pub_yr = work.find('original_publication_year').text
            b_avg_rating = work.find('average_rating').text
            b_ratings_count = work.find('ratings_count').text
            b_txt_rev_count = work.find('text_reviews_count').text
            a_id = work.find('best_book/author/id').text
            results = pd.Series((b_id, gr_title, nyt_title, b_count, pub_day, pub_mon, pub_yr, b_avg_rating, b_ratings_count, b_txt_rev_count, a_id, author))
            df = df.append(results, ignore_index=True)
            break
    return df

# %% [raw]
# test_url = 'https://www.goodreads.com/search.xml?q=%22R%22+Is+for+Ricochet+%2B+Sue+Grafton&key=2Kp7IGlO7GKjmAASOT2pEw'
# soup = try_url(test_url)

# %% [raw]
# lst = search_urls[test_url]
# results = ET.fromstring(str(soup.find('results')))
# works = results.findall('work')
# author = lst[0].decode('utf-8')
# nyt_title = lst[1]
# print author, nyt_title
# df = pd.DataFrame(data=None)
# print get_search_data(works, author, nyt_title, df)

# %%
#get data by title, author from search API
books_df = pd.DataFrame(data=None)
count = 0

for url, lst in search_urls.items():
    soup = try_url(url)
    results = ET.fromstring(str(soup.find('results')))
    works = results.findall('work')
    author = lst[0].decode('utf-8')
    nyt_title = lst[1]
    books_df = get_search_data(works, author, nyt_title, books_df)
    count += 1
    print nyt_title, count
    sleep(1.5)
# Out:
# Night Broken 1
# Bay of Sighs 2
# The Prodigal Daughter 3
# Something of Value 4
# Private L.A. 5
# The Spy Who Came in from the Cold 6
# Double Cross 7
# Just Take My Heart 8
# Scruples 9
# 3rd Degree 10
# Tick Tock 11
# Black Notice 12
# Ten Big Ones 13
# The 6th Target 14
# The Icarus Agenda 15
# The Wise Man's Fear 16
# Changes 17
# The Gift 18
# Once Is Not Enough 19
# Arch of Triumph 20
# Smokin' Seventeen 21
# The Chosen 22
# Dreamcatcher 23
# The Shadow of Your Smile 24
# Threat Vector 25
# Honeymoon 26
# How Stella Got Her Groove Back 27
# The Source 28
# Bleachers 29
# The Nanny Diaries 30
# Promises in Death 31
# Under the Dome 32
# Just One Evil Act 33
# Devices and Desires 34
# Kingsblood Royal 35
# By Love Possessed 36
# Private Games 37
# Point of Origin 38
# The Talisman 39
# Sincerely, Willis Wayde 40
# Gerald's Game 41
# Cross 42
# Lean Mean Thirteen 43
# Bloodline 44
# Second Honeymoon 45
# Fine Things 46
# Politically Correct Bedtime Stories 47
# A Feast for Crows 48
# A Wanted Man 49
# The Secret Pilgrim 50
# Finger Lickin' Fifteen 51
# Water for Elephants 52
# Fearless Fourteen 53
# Inferno 54
# A Breath of Snow and Ashes 55
# The Runaway Jury 56
# I'll Take Manhattan 57
# 1st to Die 58
# Special Delivery 59
# The Force Unleashed 60
# Valley of the Dolls 61
# The Girl Who Kicked the Hornets' Nest 62
# Centennial 63
# Polar Shift 64
# So Little Time 65
# The Nightingale 66
# The Green Years 67
# An Indecent Obsession 68
# The Razor's Edge 69
# Prey 70
# The Salzburg Connection 71
# The Last Patriot 72
# Skeleton Crew 73
# The King's General 74
# The Parsifal Mosaic 75
# The Whole Truth 76
# At Risk 77
# The Obsession 78
# Don't Go Near the Water 79
# A Great Reckoning 80
# Lifeguard 81
# Herzog 82
# The Last Man 83
# Nineteen Minutes 84
# Pretend You Don't See Her 85
# Calculated in Death 86
# Exodus 87
# Topaz 88
# The Five People You Meet in Heaven 89
# Predator 90
# Sizzling Sixteen 91
# The Hero 92
# The Girl with the Dragon Tattoo 93
# Treachery in Death 94
# A Man in Full 95
# Extreme Measures 96
# Chesapeake 97
# The Hollow Hills 98
# Brotherhood In Death 99
# Andersonville 100
# Long Lost 101
# The Best of Me 102
# The Jester 103
# B.F.'s Daughter 104
# Sleeping Murder 105
# Taltos 106
# Intensity 107
# Bittersweet 108
# Make Me 109
# A Widow for One Year 110
# Space 111
# The Little Drummer Girl 112
# From Potter's Field 113
# The Day of the Jackal 114
# Dragon Seed 115
# The Broker 116
# Sole Survivor 117
# Northern Lights 118
# South of Broad 119
# A Painted House 120
# The Defector 121
# The Scarecrow 122
# Captivated by You 123
# Oliver's Story 124
# "P" Is for Peril 125
# Friction 126
# Heir to the Empire 127
# Lord Vanity 128
# Gray Mountain 129
# The Lake House 677
# Suzanne's Diary for Nicholas 678
# The Lincoln Lawyer 679
# Primary Colors 680
# Dead and Gone 681
# Written in My Own Heart's Blood 682
# A Day Late and a Dollar Short 683
# Falconer 684
# The Brethren 685
# You've Been Warned 686
# World Without End 687
# Gone 688
# Seven Days in May 689
# The Last Hurrah 690
# Invisible 691
# The 9th Judgment 692
# Memnoch the Devil 693
# The Egyptian 694
# On the Street Where You Live 695
# 12th of Never 696
# Burr 697
# Curtain 698
# First Among Equals 699
# Joy Street 700
# Harry Potter and the Philosopher's Stone 701
# Servant of the Bones 702
# Duma Key 703
# Doctor Zhivago 704
# The Eyes of the Dragon 705
# Twelve Sharp 706
# The Cardinal of the Kremlin 707
# Ship of Fools 708
# Hot Six 709
# The Celestine Prophecy 710
# Deliver us from Evil 711
# Beach Road 712
# North and South 713
# 1876 714
# The Deep End of the Ocean 715
# Dead Reckoning 716
# Not as a Stranger 717
# The Rising 718
# The Bourne Ultimatum 719
# To the Nines 720
# First Family 721
# Beach Music 722
# The Appeal 723
# Everything's Eventual 724
# Peyton Place 725
# "...And Ladies of the Club" 726
# Red Mist 727
# The Matarese Circle 728
# The Chance 729
# Gone Tomorrow 730
# The Love Machine 731
# Unlucky 13 732
# The Girl Who Loved Tom Gordon 733
# Turbo Twenty-three 734
# Hold Tight 735
# The Satanic Verses 736
# The Help 737
# Top Secret Twenty-One 738
# Alaska 739
# The Plains of Passage 740
# Grey 741
# Stone Cold 742
# Flood Tide 743
# Lie Down with Lions 744
# The Naked and the Dead 745
# Finders Keepers 746
# Takedown Twenty 747

# %%
len(books_df)
# Out:
# 742

# %%
columns = {0: 'b_id',
           1: 'gr_title',
           2: 'nyt_title',
           3: 'b_count',
           4: 'pub_day',
           5: 'pub_mon',
           6: 'pub_yr',
           7: 'b_avg_rating',
           8: 'b_ratings_count',
           9: 'b_txt_rev_count',
           10: 'a_id',
           11: 'author'}
books_df.rename(columns=columns, inplace=True)

# %% [markdown]
# Check which books did not return results from goodreads.

# %%
gr_titles = set(books_df['nyt_title'])
nyt_titles = set(books.keys())
missing_titles = nyt_titles.difference(gr_titles)

# %%
for title in missing_titles:
    print title, books[title]
# Out:
# Primary Colors Anonymous
# Later revealed to be Joe Klein
# Isle of Dog Patricia Cornwell
# Gentlemen's Agreement Laura Z. Hobson
# From Here to Eternity James Jones
# Just One Evil Act Elizabeth George

# %%
len(missing_titles)
# Out:
# 5

# %%
with open('../data/raw/books_scraped.pkl', 'wb') as picklefile:
    pickle.dump(books_df, picklefile)

# %% [markdown]
# ### Get info about an author by id
#
# url = https://www.goodreads.com/author/show/18541?format=xml&key=2Kp7IGlO7GKjmAASOT2pEw
#
# Requires
# * author ID
#
# Returns
# * in author
#     * fans_count: number of fans on goodreads
#     * works_count: number of works
#     * gender: m/f
#     * hometown: hometown
#     * born_at: date of birth
#     * died_at: date of death
#
# _add these if necessary LATER_:
# * in author>books>book[1]>authors>author[1]
#     * average_rating: average rating for author
#     * ratings_count: total ratings for author
#     * text_reviews_count: total number of reviews for author

# %%
with open('../data/raw/books_scraped.pkl', 'rb') as picklefile:
    books_df = pickle.load(picklefile)

# %%
a_ids = books_df['a_id'].drop_duplicates()
len(a_ids)
# Out:
# 241

# %%
def get_author_data(author, a_id, df):
    '''
    Retrieve data from author xml tree on author page
    '''
    a_fans_count = author.find('fans_count').text
    a_works_count = author.find('works_count').text
    gender = author.find('gender').text
    hometown = author.find('hometown').text
    birth_date = author.find('born_at').text
    death_date = author.find('died_at').text
    first_book = author.find('books').find('book').find('authors').find('author')
    a_avg_rating = first_book.find('average_rating').text
    a_ratings_count = first_book.find('ratings_count').text
    a_text_reviews_count = first_book.find('text_reviews_count').text
    results = pd.Series((a_id, a_fans_count, a_works_count, gender, hometown, birth_date, death_date, a_avg_rating, a_ratings_count, a_text_reviews_count))
    df = df.append(results, ignore_index=True)
    return df

# %%
author_base_url = 'https://www.goodreads.com/author/show/'
search_criteria = {'format': 'xml',
                  'key': key}

author_urls = {}

for a_id in a_ids:
    url = author_base_url + a_id + '?' + urllib.urlencode(search_criteria)
    author_urls[url] = a_id

# %%
#get data by author id from author API
authors_df = pd.DataFrame(data=None)
count = 0

for url, a_id in author_urls.items():
    soup = try_url(url)
    author = ET.fromstring(str(soup.find('author')))
    authors_df = get_author_data(author, a_id, authors_df)
    count += 1
    print a_id, count
    sleep(1.5)
# Out:
# 29326 1
# 150377 2
# 4725841 3
# 3849415 4
# 24978 5
# 20248 6
# 1455 7
# 6098 8
# 9222 9
# 20704 10
# 1943477 11
# 13370 12
# 10746 13
# 819789 14
# 3670 15
# 858 16
# 7577 17
# 61105 18
# 3299 19
# 4610 20
# 12833 21
# 107767 22
# 19824 23
# 388840 24
# 1730 25
# 18344 26
# 33472 27
# 45314 28
# 1415338 29
# 59605 30
# 16893 31
# 1360780 32
# 33384 33
# 1063732 34
# 23356 35
# 12455 36
# 19823 37
# 32279 38
# 674062 39
# 12605 40
# 383606 41
# 2327917 42
# 3075 43
# 9291 44
# 8719 45
# 6417 46
# 3936 47
# 93127 48
# 14610 49
# 9629 50
# 569 51
# 75516 52
# 2578 53
# 861 54
# 4882127 55
# 21004 56
# 43626 57
# 6942 58
# 7385 59
# 1825 60
# 5091 61
# 10039 62
# 16904 63
# 7128 64
# 807271 65
# 2031 66
# 32155 67
# 7995 68
# 120490 69
# 3083854 70
# 86175 71
# 300708 72
# 2001717 73
# 656983 74
# 3513 75
# 5246 76
# 3505 77
# 4464118 78
# 92960 79
# 704 80
# 46097 81
# 32202 82
# 7464 83
# 1238 84
# 339820 85
# 5353 86
# 3617 87
# 104728 88
# 9355 89
# 3620 90
# 7565 91
# 40552 92
# 3780 93
# 27991 94
# 49699 95
# 2014 96
# 463 97
# 2384 98
# 2749 99
# 5088 100
# 3167 101
# 630 102
# 128499 103
# 3500 104
# 57432 105
# 3504 106
# 8258 107
# 40563 108
# 15516 109
# 7927 110
# 12479 111
# 99044 112
# 4711 113
# 2345 114
# 127901 115
# 1077326 116
# 18411 117
# 7368903 118
# 322069 119
# 92881 120
# 3534 121
# 7717 122
# 8468 123
# 50786 124
# 1221698 125
# 5194 126
# 3389 127
# 3892 128
# 721 129
# 296437 130
# 153910 131
# 7735 132
# 346732 133
# 74572 134
# 982213 135
# 18282 136
# 17061 137
# 26372 138
# 22665 139
# 2533 140
# 3447 141
# 1239 142
# 4917067 143
# 31321 144
# 12470 145
# 97157 146
# 7130 147
# 156078 148
# 1357577 149
# 545 150
# 38550 151
# 108424 152
# 50026 153
# 5293 154
# 316 155
# 9068 156
# 48143 157
# 36714 158
# 188932 159
# 6252 160
# 6474348 161
# 4116 162
# 222948 163
# 5197 164
# 123715 165
# 4176632 166
# 6268 167
# 78901 168
# 1025097 169
# 48206 170
# 15328 171
# 76243 172
# 24556 173
# 54915 174
# 6218 175
# 4820 176
# 3441 177
# 5152 178
# 42572 179
# 24689 180
# 6540057 181
# 28024 182
# 28186 183
# 6997290 184
# 625 185
# 2778055 186
# 2331 187
# 2383 188
# 108940 189
# 5918 190
# 9559 191
# 941441 192
# 33590 193
# 8203 194
# 5768 195
# 22485 196
# 5772434 197
# 4430 198
# 2617 199
# 221554 200
# 5657 201
# 29085 202
# 71955 203
# 43719 204
# 242659 205
# 7305 206
# 194243 207
# 54493 208
# 12584 209
# 344522 210
# 66622 211
# 82601 212
# 706255 213
# 77616 214
# 17065 215
# 2865170 216
# 45336 217
# 4391 218
# 7902 219
# 15590 220
# 8732 221
# 4372391 222
# 9550 223
# 281810 224
# 7625163 225
# 86785 226
# 14255 227
# 585 228
# 44061 229
# 5858 230
# 9212 231
# 766586 232
# 14989 233
# 6878 234
# 129457 235
# 7330 236
# 9020 237
# 19708 238
# 1411964 239
# 6160 240
# 20849 241

# %%
columns = {0: 'a_id',
           1: 'a_fans_count',
           2: 'a_works_count',
           3: 'gender',
           4: 'hometown',
           5: 'birth_date',
           6: 'death_date',
           7: 'a_avg_rating',
           8: 'a_ratings_count',
           9: 'a_text_reviews_count'}
authors_df.rename(columns=columns, inplace=True)

# %%
len(authors_df)
# Out:
# 241

# %%
with open('../data/raw/authors_scraped.pkl', 'wb') as picklefile:
    pickle.dump(authors_df, picklefile)

# %% [markdown]
# ### Get info about book by book id
#
# url = https://www.goodreads.com/book/show/1017661?key=2Kp7IGlO7GKjmAASOT2pEw
#
# Requires
# * book ID
#
# Returns
# * in book
#     * publisher: Publisher
#     * rating_dist: distribution of ratings

# %%
with open('../data/raw/books_scraped.pkl', 'rb') as picklefile:
    books_df = pickle.load(picklefile)

# %%
b_ids = books_df['b_id']

# %%
books_base_url = 'https://www.goodreads.com/book/show/'
search_criteria = {'key': key}

books_urls = {}

for b_id in b_ids:
    url = books_base_url + b_id + '?' + urllib.urlencode(search_criteria)
    books_urls[url] = b_id

# %%
def get_ratings_dist(rating_dist):
    for i in range(0, 5):
        yield rating_dist[i].split(':')[1]

# %%
def get_book_data(book, b_id, df):
    '''
    Retrieve data from books xml tree on author paginate page
    '''
    publisher = book.find('publisher').text
    rating_dist = book.find('work').find('rating_dist').text.split('|')
    ratings = get_ratings_dist(rating_dist)
    fives, fours, threes, twos, ones = get_ratings_dist(rating_dist)
    results = pd.Series((b_id, publisher, fives, fours, threes, twos, ones))
    return df.append(results, ignore_index=True)

# %%
#get data by book id from book info API
pubs_df = pd.DataFrame(data=None)
count = 0

for url, b_id in books_urls.items():
    soup = try_url(url)
    book = ET.fromstring(str(soup.find('book')))
    pubs_df = get_book_data(book, b_id, pubs_df)
    count += 1
    print b_id, count
    sleep(1.5)
# Out:
# 7675 1
# 65948 2
# 114132 3
# 2211221 4
# 968 5
# 5551522 6
# 15791154 7
# 2336803 8
# 419346 9
# 368819 10
# 20448515 11
# 2029927 12
# 778285 13
# 6892870 14
# 13888 15
# 59851 16
# 15806231 17
# 7856305 18
# 864777 19
# 7905092 20
# 17707605 21
# 1629007 22
# 4527502 23
# 152402 24
# 5064 25
# 321552 26
# 18527947 27
# 140060 28
# 49501 29
# 46020 30
# 5509321 31
# 7936809 32
# 2306910 33
# 26216087 34
# 457457 35
# 85733 36
# 2003767 37
# 26236956 38
# 201972 39
# 2429135 40
# 7926242 41
# 479415 42
# 7156505 43
# 32692 44
# 5739373 45
# 21484 46
# 19288043 47
# 815721 48
# 6526 49
# 7277715 50
# 30347 51
# 18775247 52
# 552887 53
# 82807 54
# 9420 55
# 85958 56
# 124931 57
# 3268926 58
# 198331 59
# 1528385 60
# 84573 61
# 319136 62
# 7869 63
# 6425 64
# 350065 65
# 85322 66
# 43884 67
# 8437913 68
# 1215032 69
# 7096123 70
# 419542 71
# 278102 72
# 401942 73
# 28815364 74
# 282659 75
# 994663 76
# 3431 77
# 2029176 78
# 27525 79
# 13007638 80
# 5350 81
# 59897 82
# 5093 83
# 315511 84
# 179780 85
# 86424 86
# 40317 87
# 25324116 88
# 170641 89
# 32682 90
# 10920 91
# 279416 92
# 31623 93
# 79852 94
# 110694 95
# 7604 96
# 13600318 97
# 23346918 98
# 270521 99
# 722367 100
# 13359067 101
# 85459 102
# 8315872 103
# 32669 104
# 4588 105
# 122205 106
# 18869969 107
# 826542 108
# 77239 109
# 45169 110
# 43330 111
# 25615133 112
# 3462 113
# 15746 114
# 88890 115
# 644949 116
# 237114 117
# 106648 118
# 3675828 119
# 419562 120
# 12659 121
# 35063 122
# 3100126 123
# 438168 124
# 12467 125
# 2731276 126
# 17348314 127
# 7091488 128
# 93517 129
# 6400090 130
# 699678 131
# 551931 132
# 123598 133
# 119091 134
# 29354916 135
# 581811 136
# 28686830 137
# 16130723 138
# 392217 139
# 10585 140
# 6307651 141
# 32505 142
# 86663 143
# 576666 144
# 292455 145
# 1017661 146
# 3199179 147
# 10584 148
# 116053 149
# 2149535 150
# 3492020 151
# 159346 152
# 5113 153
# 14554 154
# 161361 155
# 10808006 156
# 262229 157
# 3720975 564
# 572762 565
# 1248179 566
# 17407748 567
# 13147 568
# 10644930 569
# 41699 570
# 17333279 571
# 392263 572
# 6858 573
# 4406 574
# 158417 575
# 12657 576
# 6455256 577
# 17660 578
# 17876893 579
# 1166599 580
# 18989 581
# 2095583 582
# 315272 583
# 28220985 584
# 21445 585
# 17899950 586
# 219919 587
# 22076 588
# 6531 589
# 78987 590
# 268275 591
# 4656 592
# 13708346 593
# 597790 594
# 10664113 595
# 11564 596
# 2029177 597
# 10929 598
# 10603 599
# 24820165 600
# 42696 601
# 5349 602
# 27691 603
# 6048530 604
# 39662 605
# 7304203 606
# 401921 607
# 56893 608
# 83674 609
# 113435 610
# 19486421 611
# 28186363 612
# 503994 613
# 11732634 614
# 7743175 615
# 14866 616
# 34941 617
# 1048940 618
# 7997069 619
# 13497 620
# 5368 621
# 19003 622
# 5161 623
# 5355 624
# 82817 625
# 504420 626
# 19561922 627
# 21853621 628
# 13573622 629
# 18353714 630
# 5351 631
# 18114060 632
# 17570105 633
# 140974 634
# 11082037 635
# 15745950 636
# 5 637
# 119073 638
# 22034 639
# 368772 640
# 5348 641
# 82795 642
# 25337081 643
# 11573 644
# 320167 645
# 18143977 646
# 23190986 647
# 17333223 648
# 326672 649
# 8722 650
# 413616 651
# 227711 652
# 10692 653
# 410445 654
# 11570 655
# 10607 656
# 3410425 657
# 71728 658
# 32442 659
# 216443 660
# 13596809 661
# 1189684 662
# 40440 663
# 1293866 664
# 20707959 665
# 27326 666
# 228560 667
# 571555 668
# 19494 669
# 32429 670
# 10818853 671
# 7959473 672
# 8045080 673
# 2666 674
# 43357 675
# 142079 676
# 6135237 677
# 183265 678
# 12232938 679
# 4987 680
# 16158558 681
# 5060378 682
# 3063499 683
# 82798 684
# 7860860 685
# 947216 686
# 3464 687
# 723668 688
# 6193821 689
# 5357 690
# 10816297 691
# 350039 692
# 43780 693
# 25387351 694
# 17262159 695
# 7278752 696
# 338687 697
# 31338 698
# 23153154 699
# 7933437 700
# 15985392 701
# 15985348 702
# 122209 703
# 6424 704
# 18007564 705
# 7667 706
# 24940998 707
# 50930 708
# 24950845 709
# 12661 710
# 81903 711
# 1546165 712
# 20881071 713
# 13145 714
# 3313418 715
# 1713912 716
# 26109394 717
# 10605 718
# 6585201 719
# 19670 720
# 31196 721
# 154423 722
# 3507 723
# 4035 724
# 6541 725
# 691775 726
# 18656055 727
# 11588 728
# 10567 729
# 1877857 730
# 41490 731
# 29093764 732
# 19486412 733
# 22557272 734
# 84049 735
# 59881 736
# 191139 737

# %%
columns = {0: 'b_id',
           1: 'publisher',
           2: 'b_rating_5_count',
           3: 'b_rating_4_count',
           4: 'b_rating_3_count',
           5: 'b_rating_2_count',
           6: 'b_rating_1_count',}

pubs_df.rename(columns=columns, inplace=True)

# %%
books_df = books_df.merge(pubs_df, on='b_id')

# %%
with open('../data/raw/books_scraped.pkl', 'wb') as picklefile:
    pickle.dump(books_df, picklefile)
